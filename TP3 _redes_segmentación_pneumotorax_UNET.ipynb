# %%
from PIL import Image
import numpy as np
import albumentations as A
from pathlib import Path

# %%
# instalar API de Kaggle y crear directorio y archivo para configurarla
# !pip install --user kaggle
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
import json

# completar con su información de usuario de Kaggle
api_token = {"username": "pedrolucasbarrera", "key": "6fb6bc323d0a19e6de629855b120ec60"}

with open('/root/.kaggle/kaggle.json','w') as file:
    json.dump(api_token,file)

# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# /bin/bash: chmod 600 ~/.kaggle/kaggle.json: No such file or directory

# %%
# descargar y descomprimir dataset
# !kaggle datasets download -d vbookshelf/pneumothorax-chest-xray-images-and-masks
# !unzip pneumothorax-chest-xray-images-and-masks.zip

# %%
# definir las transformaciones para aumentación de datos
'''

Transformaciones disponibles:
https://github.com/albumentations-team/albumentations#pixel-level-transforms

ejemplo de transformación compuesta:

transform = A.Compose([
    A.RandomRotate90(),
    A.Transpose()
])

'''
transform = False

# %%
import tensorflow as tf
import random
 
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, path, img_prefix, mask_prefix, transform=False, batch_size=4, dim=(128,128), train=True, val = False,n_channels=1, shuffle=True):
        'Initialization'
        self.path = path
        self.transform = transform
        self.n_channels = n_channels
        self.img_prefix = img_prefix
        self.mask_prefix = mask_prefix
        self.batch_size = batch_size
        self.dim = dim
        self.shuffle = shuffle
        if train:
            files = [file.name for file in Path(path).glob("png_images/*train*1_.png")]
            self.filenames = files[0:(int(len(files)/100*90))]
            random.seed(4)
            random.shuffle(self.filenames)
        elif val:
            files = [file.name for file in Path(path).glob("png_images/*train*1_.png")]
            self.filenames = files[(int(len(files)/100*90)):]
            random.seed(4)
            np.random.shuffle(self.filenames)

        else:
            self.filenames = [file.name for file in Path(path).glob("png_images/*test*1_.png")]
            random.seed(4)
            np.random.shuffle(self.filenames)
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.filenames) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]

        # Generate data
        X, y = self.__data_generation(filenames)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            np.random.shuffle(self.filenames)

    def __data_generation(self, filenames):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size, *self.dim, self.n_channels))
        
        # Generate data
        for i, filename in enumerate(filenames):
            img = Image.open(self.path + self.img_prefix + filename).resize(self.dim)
            mask = Image.open(self.path + self.mask_prefix + filename).resize(self.dim)
            if self.transform:
                trf = self.transform(image = np.array(img), mask = np.array(mask))
                X[i,...] = trf['image'].reshape(*self.dim, self.n_channels)/255.
                y[i,...] = trf['mask'].reshape(*self.dim, self.n_channels)/255.
            else:
                X[i,...] = np.array(img).reshape(*self.dim, self.n_channels)/255.
                y[i,...] = np.array(mask).reshape(*self.dim, self.n_channels)/255.
        return X,y

# %%
# tener cuidado con la selección del tamaño del batch. Al iniciar el entrenamiento
# dependiendo del tamaño de la red y el tamaño del batch, puede surgir un error OOM
# (out of memory) debido a las limitaciones de RAM de la GPU.
# En tal caso se deberá achicar el tamaño del batch

# %%
def datagen(batch, train, val, transformm = False):
  datagen_val = DataGenerator(
      'siim-acr-pneumothorax/',
      "png_images/",
      "png_masks/",
      transform = transformm,
      batch_size = batch,
      train = train,
      val = val
      )
  return datagen_val

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Input, BatchNormalization, Dropout, Concatenate, MaxPooling2D, UpSampling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import backend as K

# %%
# definición del coeficiente de Dice
def dice_coef(y_true, y_pred, smooth=1.0):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

# función de costo que combina binary crossentropy con Dice
def dice_coef_loss(y_true, y_pred):
    dice_term = 1 - dice_coef(y_true, y_pred)
    bce = tf.keras.losses.BinaryCrossentropy()
    loss = dice_term * 0.5 + bce(y_true, y_pred)*0.5
    return loss

# %%
# definición de bloques para armar la arquitectura de UNet

def conv_block(m, dim, acti, bn, res, do=0):
	n = Conv2D(dim, 3, activation=acti, padding='same')(m)
	n = BatchNormalization()(n) if bn else n
	n = Dropout(do)(n) if do else n
	n = Conv2D(dim, 3, activation=acti, padding='same')(n)
	n = BatchNormalization()(n) if bn else n
	return Concatenate()([m, n]) if res else n

def level_block(m, dim, depth, inc, acti, do, bn, mp, up, res):
	if depth > 0:
		n = conv_block(m, dim, acti, bn, res)
		m = MaxPooling2D()(n) if mp else Conv2D(dim, 3, strides=2, padding='same')(n)
		m = level_block(m, int(inc*dim), depth-1, inc, acti, do, bn, mp, up, res)
		if up:
			m = UpSampling2D()(m)
			m = Conv2D(dim, 2, activation=acti, padding='same')(m)
		else:
			m = Conv2DTranspose(dim, 3, strides=2, activation=acti, padding='same')(m)
		n = Concatenate()([n, m])
		m = conv_block(n, dim, acti, bn, res)
	else:
		m = conv_block(m, dim, acti, bn, res, do)
	return m

def UNet(img_shape, out_ch=1, start_ch=64, depth=4, inc_rate=2., activation='relu', 
		 dropout=0.5, batchnorm=False, maxpool=True, upconv=True, residual=False):
	i = Input(shape=img_shape)
	o = level_block(i, start_ch, depth, inc_rate, activation, dropout, batchnorm, maxpool, upconv, residual)
	o = Conv2D(out_ch, 1, activation='sigmoid')(o)
	return Model(inputs=i, outputs=o)

# %%
import matplotlib.pyplot as plt

# %%
def Plot_loss(history): 
  plt.plot(history.history["loss"],label="Train")
  plt.plot(history.history["val_loss"],label="Val")
  plt.title("loss")
  plt.legend()
  plt.show()

  plt.plot(history.history["binary_crossentropy"],label="Train")
  plt.plot(history.history["val_binary_crossentropy"],label="Val")

  plt.title("binary_crossentropy")
  plt.legend()
  plt.show()

  plt.plot(history.history["dice_coef"],label="Train")
  plt.plot(history.history["val_dice_coef"],label="Val")

  plt.title("dice_coef")
  plt.legend()
  plt.show()

# %%
def graficar_pred(data, pred):
  for idx in range(4):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
    ax1.imshow(data[0][0][idx].reshape(128,128))
    ax1.set_title(f'Imagen {idx+1}')
    ax2.imshow(data[0][1][idx].reshape(128,128))
    ax2.set_title(f'Mask {idx+1}')
    ax3.imshow(pred[idx].reshape(128,128))
    ax3.set_title(f'Predicción {idx+1}')

# %% [markdown]
# ##Modelo 1
#
# En esta ocasión se entrenó una UNET con los siguientes parametros:
# - Profundidad = 5
# - Batchnormalization = False
# - Batchsize = 64
# - Cantidad de imagenes de Train = 90% de las de train
# - Cantidad de imagenes de Val = 10% de las de train
# - Cantidad de imagenes de Test = Todas
# - Epochs = 10
# - DataAugmentation = No

# %%
batch = 64
batchnorm = False
depth = 5
dropout = False
epochs = 20

# %%
datagen_train_1 = datagen(batch = batch, train = True , val = False, transformm = False)
datagen_val_1 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_1 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model1 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model1.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history1 = model1.fit(datagen_train_1, epochs = 10, validation_data=datagen_val_1)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 60s 2s/step - loss: 0.8332 - binary_crossentropy: 0.6864 - dice_coef: 0.0200 - val_loss: 0.5166 - val_binary_crossentropy: 0.0686 - val_dice_coef: 0.0355
# Epoch 2/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.4946 - binary_crossentropy: 0.0744 - dice_coef: 0.0852 - val_loss: 0.4826 - val_binary_crossentropy: 0.0942 - val_dice_coef: 0.1291
# Epoch 3/10
# 33/33 [==============================] - 57s 2s/step - loss: 0.4656 - binary_crossentropy: 0.0843 - dice_coef: 0.1530 - val_loss: 0.4577 - val_binary_crossentropy: 0.0944 - val_dice_coef: 0.1791
# Epoch 4/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.4448 - binary_crossentropy: 0.0832 - dice_coef: 0.1937 - val_loss: 0.4464 - val_binary_crossentropy: 0.0831 - val_dice_coef: 0.1902
# Epoch 5/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.4220 - binary_crossentropy: 0.0809 - dice_coef: 0.2369 - val_loss: 0.4104 - val_binary_crossentropy: 0.0917 - val_dice_coef: 0.2709
# Epoch 6/10
# 33/33 [==============================] - 57s 2s/step - loss: 0.4008 - binary_crossentropy: 0.0800 - dice_coef: 0.2783 - val_loss: 0.4077 - val_binary_crossentropy: 0.0938 - val_dice_coef: 0.2783
# Epoch 7/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.3888 - binary_crossentropy: 0.0783 - dice_coef: 0.3008 - val_loss: 0.3807 - val_binary_crossentropy: 0.0698 - val_dice_coef: 0.3083
# Epoch 8/10
# 33/33 [==============================] - 57s 2s/step - loss: 0.3766 - binary_crossentropy: 0.0759 - dice_coef: 0.3227 - val_loss: 0.3785 - val_binary_crossentropy: 0.0739 - val_dice_coef: 0.3169
# Epoch 9/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.3689 - binary_crossentropy: 0.0754 - dice_coef: 0.3377 - val_loss: 0.3766 - val_binary_crossentropy: 0.0921 - val_dice_coef: 0.3389
# Epoch 10/10
# 33/33 [==============================] - 56s 2s/step - loss: 0.3549 - binary_crossentropy: 0.0722 - dice_coef: 0.3625 - val_loss: 0.3730 - val_binary_crossentropy: 0.0721 - val_dice_coef: 0.3261

# %%
preds_train1 = model1.predict(datagen_train_1)
preds_test1 = model1.predict(datagen_test_1)
# Out:
# 33/33 [==============================] - 45s 1s/step
# 4/4 [==============================] - 5s 1s/step

# %%
Plot_loss(history1)

# %%
print("TRAIN")
graficar_pred(datagen_train_1,preds_train1)
print("TEST")
graficar_pred(datagen_test_1,preds_test1)
# Out:
# TRAIN
# TEST

# %%
model1.evaluate(datagen_test_1)
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 0.3780 - binary_crossentropy: 0.0710 - dice_coef: 0.3149
# [0.37804707884788513, 0.07098247110843658, 0.3148882985115051]

# %% [markdown]
# Se ve que el modelo tiene capacidad de aumentar el overfitting al aumentar los epochs.

# %% [markdown]
# ##Modelo 2
#
# En esta ocasión se entrenó una UNET con los siguientes parametros:
# - Profundidad = 3
# - Batchnormalization = False
# - Batchsize = 128
# - Cantidad de imagenes de Train = 90% de las de train
# - Cantidad de imagenes de Val = 10% de las de train
# - Cantidad de imagenes de Test = Todas
# - Epochs = 20
# - DataAugmentation = No
#
# Se eligió profundidad de 3 porque al elegir 5 tiraba el error "Graph error" y no me dejaba continuar.

# %%
batch = 128
batchnorm = False
depth = 3
dropout = False
epochs = 20

# %%
datagen_train_2 = datagen(batch = batch, train = True , val = False, transformm = False)
datagen_val_2 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_2 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model2 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model2.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history2 = model2.fit(datagen_train_2, epochs = epochs, validation_data=datagen_val_2)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 58s 3s/step - loss: 0.5951 - binary_crossentropy: 0.2019 - dice_coef: 0.0117 - val_loss: 0.5312 - val_binary_crossentropy: 0.0758 - val_dice_coef: 0.0134
# Epoch 2/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.5208 - binary_crossentropy: 0.0718 - dice_coef: 0.0301 - val_loss: 0.5140 - val_binary_crossentropy: 0.0652 - val_dice_coef: 0.0372
# Epoch 3/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.5062 - binary_crossentropy: 0.0736 - dice_coef: 0.0612 - val_loss: 0.5026 - val_binary_crossentropy: 0.0735 - val_dice_coef: 0.0683
# Epoch 4/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4930 - binary_crossentropy: 0.0807 - dice_coef: 0.0946 - val_loss: 0.4963 - val_binary_crossentropy: 0.0789 - val_dice_coef: 0.0863
# Epoch 5/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4824 - binary_crossentropy: 0.0809 - dice_coef: 0.1160 - val_loss: 0.4710 - val_binary_crossentropy: 0.0720 - val_dice_coef: 0.1300
# Epoch 6/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4630 - binary_crossentropy: 0.0849 - dice_coef: 0.1589 - val_loss: 0.4651 - val_binary_crossentropy: 0.0970 - val_dice_coef: 0.1669
# Epoch 7/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4402 - binary_crossentropy: 0.0845 - dice_coef: 0.2040 - val_loss: 0.4457 - val_binary_crossentropy: 0.1146 - val_dice_coef: 0.2231
# Epoch 8/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4252 - binary_crossentropy: 0.0842 - dice_coef: 0.2339 - val_loss: 0.4350 - val_binary_crossentropy: 0.1070 - val_dice_coef: 0.2371
# Epoch 9/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4192 - binary_crossentropy: 0.0812 - dice_coef: 0.2428 - val_loss: 0.4221 - val_binary_crossentropy: 0.0846 - val_dice_coef: 0.2405
# Epoch 10/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4072 - binary_crossentropy: 0.0809 - dice_coef: 0.2666 - val_loss: 0.4005 - val_binary_crossentropy: 0.0805 - val_dice_coef: 0.2796
# Epoch 11/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4103 - binary_crossentropy: 0.0829 - dice_coef: 0.2622 - val_loss: 0.4149 - val_binary_crossentropy: 0.0864 - val_dice_coef: 0.2565
# Epoch 12/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3978 - binary_crossentropy: 0.0792 - dice_coef: 0.2837 - val_loss: 0.3849 - val_binary_crossentropy: 0.0784 - val_dice_coef: 0.3085
# Epoch 13/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3876 - binary_crossentropy: 0.0767 - dice_coef: 0.3014 - val_loss: 0.3792 - val_binary_crossentropy: 0.0744 - val_dice_coef: 0.3160
# Epoch 14/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3843 - binary_crossentropy: 0.0772 - dice_coef: 0.3087 - val_loss: 0.3742 - val_binary_crossentropy: 0.0860 - val_dice_coef: 0.3377
# Epoch 15/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3793 - binary_crossentropy: 0.0769 - dice_coef: 0.3182 - val_loss: 0.3657 - val_binary_crossentropy: 0.0773 - val_dice_coef: 0.3458
# Epoch 16/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3651 - binary_crossentropy: 0.0753 - dice_coef: 0.3451 - val_loss: 0.3835 - val_binary_crossentropy: 0.0881 - val_dice_coef: 0.3212
# Epoch 17/20
# 16/16 [==============================] - 53s 3s/step - loss: 0.3634 - binary_crossentropy: 0.0728 - dice_coef: 0.3459 - val_loss: 0.3741 - val_binary_crossentropy: 0.0782 - val_dice_coef: 0.3300
# Epoch 18/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3644 - binary_crossentropy: 0.0748 - dice_coef: 0.3460 - val_loss: 0.3945 - val_binary_crossentropy: 0.0690 - val_dice_coef: 0.2800
# Epoch 19/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3640 - binary_crossentropy: 0.0729 - dice_coef: 0.3449 - val_loss: 0.3719 - val_binary_crossentropy: 0.0820 - val_dice_coef: 0.3382
# Epoch 20/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3538 - binary_crossentropy: 0.0719 - dice_coef: 0.3643 - val_loss: 0.3572 - val_binary_crossentropy: 0.0707 - val_dice_coef: 0.3562

# %%
preds_train2 = model2.predict(datagen_train_2)
preds_test2 = model2.predict(datagen_test_2)
# Out:
# 16/16 [==============================] - 42s 3s/step
# 2/2 [==============================] - 5s 3s/step

# %%
Plot_loss(history2)

# %%
print("TRAIN")
graficar_pred(datagen_train_2,preds_train2)
print("TEST")
graficar_pred(datagen_test_2,preds_test2)

# %%
model2.evaluate(datagen_test_2)
# Out:
# 2/2 [==============================] - 6s 3s/step - loss: 0.3723 - binary_crossentropy: 0.0724 - dice_coef: 0.3278
# [0.3722940683364868, 0.07235215604305267, 0.32776397466659546]

# %% [markdown]
# Se consiguio un coeficiente de dice de test y coeficientedes de dice y loss de tanto validadion como train muy similares al caso con 64 de batch size. Pareciera por los graficos de dice y de loss que el sistema tiene aun capacidad para overfitting si se aumentaran los epochs.

# %% [markdown]
# ##Modelo 3
#
# En esta ocasión se entrenó una UNET con los mismos parametros que el anterior pero usando batchnormalization ,dado que se posee un bathsize lo suficientemente grande(128).

# %%
batch = 128
batchnorm = True
depth = 3
dropout = False
epochs = 20

# %%
datagen_train_3 = datagen(batch = batch, train = True , val = False, transformm = False)
datagen_val_3 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_3 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model3 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model3.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history3 = model3.fit(datagen_train_3, epochs = epochs, validation_data=datagen_val_3)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 158s 4s/step - loss: 0.5015 - binary_crossentropy: 0.1486 - dice_coef: 0.1455 - val_loss: 0.6676 - val_binary_crossentropy: 0.3617 - val_dice_coef: 0.0265
# Epoch 2/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.3982 - binary_crossentropy: 0.0799 - dice_coef: 0.2835 - val_loss: 0.5681 - val_binary_crossentropy: 0.1611 - val_dice_coef: 0.0249
# Epoch 3/20
# 16/16 [==============================] - 55s 3s/step - loss: 0.3806 - binary_crossentropy: 0.0780 - dice_coef: 0.3168 - val_loss: 0.5487 - val_binary_crossentropy: 0.1168 - val_dice_coef: 0.0194
# Epoch 4/20
# 16/16 [==============================] - 58s 4s/step - loss: 0.3626 - binary_crossentropy: 0.0741 - dice_coef: 0.3490 - val_loss: 0.5389 - val_binary_crossentropy: 0.0956 - val_dice_coef: 0.0178
# Epoch 5/20
# 16/16 [==============================] - 63s 4s/step - loss: 0.3513 - binary_crossentropy: 0.0722 - dice_coef: 0.3697 - val_loss: 0.5440 - val_binary_crossentropy: 0.0919 - val_dice_coef: 0.0040
# Epoch 6/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.3374 - binary_crossentropy: 0.0689 - dice_coef: 0.3941 - val_loss: 0.5465 - val_binary_crossentropy: 0.0960 - val_dice_coef: 0.0030
# Epoch 7/20
# 16/16 [==============================] - 53s 3s/step - loss: 0.3320 - binary_crossentropy: 0.0686 - dice_coef: 0.4046 - val_loss: 0.5451 - val_binary_crossentropy: 0.0932 - val_dice_coef: 0.0029
# Epoch 8/20
# 16/16 [==============================] - 60s 4s/step - loss: 0.3241 - binary_crossentropy: 0.0682 - dice_coef: 0.4201 - val_loss: 0.5465 - val_binary_crossentropy: 0.0969 - val_dice_coef: 0.0040
# Epoch 9/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.3332 - binary_crossentropy: 0.0698 - dice_coef: 0.4034 - val_loss: 0.5511 - val_binary_crossentropy: 0.1035 - val_dice_coef: 0.0013
# Epoch 10/20
# 16/16 [==============================] - 55s 3s/step - loss: 0.3020 - binary_crossentropy: 0.0631 - dice_coef: 0.4590 - val_loss: 0.5580 - val_binary_crossentropy: 0.1166 - val_dice_coef: 5.9845e-04
# Epoch 11/20
# 16/16 [==============================] - 53s 3s/step - loss: 0.2872 - binary_crossentropy: 0.0615 - dice_coef: 0.4871 - val_loss: 0.5788 - val_binary_crossentropy: 0.1576 - val_dice_coef: 1.3995e-04
# Epoch 12/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.2752 - binary_crossentropy: 0.0595 - dice_coef: 0.5092 - val_loss: 0.5848 - val_binary_crossentropy: 0.1698 - val_dice_coef: 2.0684e-04
# Epoch 13/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.2606 - binary_crossentropy: 0.0564 - dice_coef: 0.5353 - val_loss: 0.5946 - val_binary_crossentropy: 0.1892 - val_dice_coef: 6.5115e-05
# Epoch 14/20
# 16/16 [==============================] - 53s 3s/step - loss: 0.2570 - binary_crossentropy: 0.0563 - dice_coef: 0.5422 - val_loss: 0.5834 - val_binary_crossentropy: 0.1669 - val_dice_coef: 7.8257e-05
# Epoch 15/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.2483 - binary_crossentropy: 0.0558 - dice_coef: 0.5592 - val_loss: 0.5729 - val_binary_crossentropy: 0.1460 - val_dice_coef: 2.4607e-04
# Epoch 16/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.2407 - binary_crossentropy: 0.0532 - dice_coef: 0.5718 - val_loss: 0.5760 - val_binary_crossentropy: 0.1522 - val_dice_coef: 1.9654e-04
# Epoch 17/20
# 16/16 [==============================] - 56s 3s/step - loss: 0.2400 - binary_crossentropy: 0.0536 - dice_coef: 0.5737 - val_loss: 0.5889 - val_binary_crossentropy: 0.1778 - val_dice_coef: 1.0949e-04
# Epoch 18/20
# 16/16 [==============================] - 56s 3s/step - loss: 0.2328 - binary_crossentropy: 0.0523 - dice_coef: 0.5867 - val_loss: 0.5728 - val_binary_crossentropy: 0.1457 - val_dice_coef: 1.5176e-04
# Epoch 19/20
# 16/16 [==============================] - 63s 4s/step - loss: 0.2239 - binary_crossentropy: 0.0511 - dice_coef: 0.6033 - val_loss: 0.5942 - val_binary_crossentropy: 0.1885 - val_dice_coef: 6.4173e-05
# Epoch 20/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.2207 - binary_crossentropy: 0.0495 - dice_coef: 0.6081 - val_loss: 0.5664 - val_binary_crossentropy: 0.1330 - val_dice_coef: 2.2222e-04

# %%
preds_train3 = model3.predict(datagen_train_3)
preds_test3 = model3.predict(datagen_test_3)
# Out:
# 16/16 [==============================] - 54s 3s/step
# 2/2 [==============================] - 7s 4s/step

# %%
Plot_loss(history3)

# %%
print("TRAIN")
graficar_pred(datagen_train_3,preds_train3)
print("TEST")
graficar_pred(datagen_test_3,preds_test3)
# Out:
# TRAIN
# TEST

# %%
model3.evaluate(datagen_test_3)
# Out:
# 2/2 [==============================] - 6s 3s/step - loss: 0.5681 - binary_crossentropy: 0.1364 - dice_coef: 2.2797e-04
# [0.568083643913269, 0.13639527559280396, 0.00022797084238845855]

# %% [markdown]
# Puede verse que al usar batchnormalization no se consiguió una gran aceleración del training (tardó casi lo mismo) y se consiguieron mucho peores resutlados (dice cercano a 0 en train, muy malo) para test, ademas de no lograrse mucho mejores resultados para test tampoco, por lo que no pareceiera ser útil batchnormalization con batch size de 128, talvez debería usarse uno aun más grande. Pareciera demas, este modelo fue especialmente malo para clasificar imagenes que no fueran de su entrenamiento, como puede verse en el grafico del dice del conjunto de validación.
#
# En las predicciones graficas, puede verse como pareciera que no predició para ninguna imagen nada (incluido test, que es raro dado que el dice no es tan bajo). Esto, sumado al extremadamente bajo valor de val_dice y de test_dice, además del hecho de que el dice de train no es tan bajo pero aun asi pareciera no hacer ninguna predicción correctamente indica que podría haber algun error.

# %% [markdown]
# ##Modelo 4
#
# En esta ocasión se entrenó una UNET con los mismos parametros que el anterior pero realizando una transformacion de datos y sin batchnormalization

# %%
batch = 128
batchnorm = False
depth = 3
dropout = False
epochs = 20
transform = A.Compose([
    A. ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
    A.RandomBrightnessContrast()
])

# %%
datagen_train_4 = datagen(batch = batch, train = True , val = False, transformm = transform)
datagen_val_4 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_4 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model4 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model4.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history4 = model4.fit(datagen_train_4, epochs = epochs, validation_data=datagen_val_4)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 58s 3s/step - loss: 0.5932 - binary_crossentropy: 0.1982 - dice_coef: 0.0118 - val_loss: 0.5347 - val_binary_crossentropy: 0.0871 - val_dice_coef: 0.0177
# Epoch 2/20
# 16/16 [==============================] - 54s 3s/step - loss: 0.5229 - binary_crossentropy: 0.0732 - dice_coef: 0.0275 - val_loss: 0.5187 - val_binary_crossentropy: 0.0713 - val_dice_coef: 0.0339
# Epoch 3/20
# 16/16 [==============================] - 56s 3s/step - loss: 0.5117 - binary_crossentropy: 0.0692 - dice_coef: 0.0457 - val_loss: 0.5019 - val_binary_crossentropy: 0.0724 - val_dice_coef: 0.0686
# Epoch 4/20
# 16/16 [==============================] - 59s 4s/step - loss: 0.4935 - binary_crossentropy: 0.0757 - dice_coef: 0.0887 - val_loss: 0.4985 - val_binary_crossentropy: 0.0893 - val_dice_coef: 0.0922
# Epoch 5/20
# 16/16 [==============================] - 53s 3s/step - loss: 0.4835 - binary_crossentropy: 0.0839 - dice_coef: 0.1169 - val_loss: 0.4830 - val_binary_crossentropy: 0.0944 - val_dice_coef: 0.1285
# Epoch 6/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4685 - binary_crossentropy: 0.0902 - dice_coef: 0.1532 - val_loss: 0.4596 - val_binary_crossentropy: 0.0699 - val_dice_coef: 0.1507
# Epoch 7/20
# 16/16 [==============================] - 57s 3s/step - loss: 0.4505 - binary_crossentropy: 0.0844 - dice_coef: 0.1834 - val_loss: 0.4422 - val_binary_crossentropy: 0.0770 - val_dice_coef: 0.1926
# Epoch 8/20
# 16/16 [==============================] - 56s 3s/step - loss: 0.4397 - binary_crossentropy: 0.0833 - dice_coef: 0.2038 - val_loss: 0.4358 - val_binary_crossentropy: 0.0941 - val_dice_coef: 0.2225
# Epoch 9/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4313 - binary_crossentropy: 0.0844 - dice_coef: 0.2217 - val_loss: 0.4138 - val_binary_crossentropy: 0.0880 - val_dice_coef: 0.2604
# Epoch 10/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4230 - binary_crossentropy: 0.0808 - dice_coef: 0.2348 - val_loss: 0.4338 - val_binary_crossentropy: 0.0905 - val_dice_coef: 0.2229
# Epoch 11/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.4080 - binary_crossentropy: 0.0788 - dice_coef: 0.2629 - val_loss: 0.4153 - val_binary_crossentropy: 0.0951 - val_dice_coef: 0.2645
# Epoch 12/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3966 - binary_crossentropy: 0.0800 - dice_coef: 0.2867 - val_loss: 0.4179 - val_binary_crossentropy: 0.0884 - val_dice_coef: 0.2525
# Epoch 13/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.4050 - binary_crossentropy: 0.0796 - dice_coef: 0.2696 - val_loss: 0.4210 - val_binary_crossentropy: 0.0813 - val_dice_coef: 0.2392
# Epoch 14/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3963 - binary_crossentropy: 0.0816 - dice_coef: 0.2889 - val_loss: 0.4021 - val_binary_crossentropy: 0.0703 - val_dice_coef: 0.2661
# Epoch 15/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3844 - binary_crossentropy: 0.0747 - dice_coef: 0.3058 - val_loss: 0.4163 - val_binary_crossentropy: 0.0984 - val_dice_coef: 0.2657
# Epoch 16/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3851 - binary_crossentropy: 0.0772 - dice_coef: 0.3070 - val_loss: 0.3976 - val_binary_crossentropy: 0.0841 - val_dice_coef: 0.2888
# Epoch 17/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3733 - binary_crossentropy: 0.0750 - dice_coef: 0.3284 - val_loss: 0.4151 - val_binary_crossentropy: 0.0826 - val_dice_coef: 0.2523
# Epoch 18/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3788 - binary_crossentropy: 0.0776 - dice_coef: 0.3199 - val_loss: 0.3647 - val_binary_crossentropy: 0.0655 - val_dice_coef: 0.3362
# Epoch 19/20
# 16/16 [==============================] - 52s 3s/step - loss: 0.3680 - binary_crossentropy: 0.0731 - dice_coef: 0.3371 - val_loss: 0.3527 - val_binary_crossentropy: 0.0692 - val_dice_coef: 0.3638
# Epoch 20/20
# 16/16 [==============================] - 51s 3s/step - loss: 0.3555 - binary_crossentropy: 0.0723 - dice_coef: 0.3614 - val_loss: 0.3647 - val_binary_crossentropy: 0.0856 - val_dice_coef: 0.3561

# %%
preds_train4 = model4.predict(datagen_train_4)
preds_test4 = model4.predict(datagen_test_4)
# Out:
# 16/16 [==============================] - 50s 3s/step
# 2/2 [==============================] - 5s 3s/step

# %%
Plot_loss(history4)

# %%
graficar_pred(datagen_train_4,preds_train4)

graficar_pred(datagen_test_4,preds_test4)

# %%
model4.evaluate(datagen_test_4)
# Out:
# 2/2 [==============================] - 6s 3s/step - loss: 0.3822 - binary_crossentropy: 0.0889 - dice_coef: 0.3246
# [0.3821530342102051, 0.08891692012548447, 0.3246108889579773]

# %% [markdown]
# Comparando con los parametros del modelo 2,pareciera que la transformación utilizada no generó una mejora en el modelo, dado que tanto el coeficiente de dice como la loss de test y de validación dieron similares para los modelos con y sin transformacion de datos. Cabe destacar que, tanto en este modelo como en el 2, pareciera que el sistema tiene mas capacidad de overfitting que podria ser alcanzado aumentando el numero de epochs.

# %% [markdown]
# ### Modelo 5
# En este modelo se entreno con los mismos parametros que el modelo 1, pero con 50 epochs para evaluar la capacidad de overfitting.

# %%
batch = 64
batchnorm = False
depth = 5
dropout = False
epochs = 50

# %%
datagen_train_5 = datagen(batch = batch, train = True , val = False, transformm = False)
datagen_val_5 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_5 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model5 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model5.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history5 = model5.fit(datagen_train_5, epochs = epochs, validation_data=datagen_val_5)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 61s 2s/step - loss: 1.0347 - binary_crossentropy: 1.0882 - dice_coef: 0.0187 - val_loss: 0.5161 - val_binary_crossentropy: 0.0729 - val_dice_coef: 0.0406
# Epoch 2/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.4921 - binary_crossentropy: 0.0728 - dice_coef: 0.0885 - val_loss: 0.4931 - val_binary_crossentropy: 0.1029 - val_dice_coef: 0.1166
# Epoch 3/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.4674 - binary_crossentropy: 0.0868 - dice_coef: 0.1519 - val_loss: 0.4759 - val_binary_crossentropy: 0.0786 - val_dice_coef: 0.1267
# Epoch 4/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.4451 - binary_crossentropy: 0.0822 - dice_coef: 0.1921 - val_loss: 0.4567 - val_binary_crossentropy: 0.0981 - val_dice_coef: 0.1847
# Epoch 5/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.4259 - binary_crossentropy: 0.0824 - dice_coef: 0.2306 - val_loss: 0.4220 - val_binary_crossentropy: 0.0867 - val_dice_coef: 0.2427
# Epoch 6/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.4104 - binary_crossentropy: 0.0810 - dice_coef: 0.2602 - val_loss: 0.4235 - val_binary_crossentropy: 0.0888 - val_dice_coef: 0.2418
# Epoch 7/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.3992 - binary_crossentropy: 0.0797 - dice_coef: 0.2814 - val_loss: 0.4052 - val_binary_crossentropy: 0.0855 - val_dice_coef: 0.2752
# Epoch 8/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.3795 - binary_crossentropy: 0.0751 - dice_coef: 0.3161 - val_loss: 0.3892 - val_binary_crossentropy: 0.0882 - val_dice_coef: 0.3098
# Epoch 9/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.3753 - binary_crossentropy: 0.0775 - dice_coef: 0.3270 - val_loss: 0.3970 - val_binary_crossentropy: 0.0812 - val_dice_coef: 0.2873
# Epoch 10/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.3571 - binary_crossentropy: 0.0718 - dice_coef: 0.3575 - val_loss: 0.3712 - val_binary_crossentropy: 0.0858 - val_dice_coef: 0.3435
# Epoch 11/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.3455 - binary_crossentropy: 0.0715 - dice_coef: 0.3805 - val_loss: 0.3776 - val_binary_crossentropy: 0.0695 - val_dice_coef: 0.3143
# Epoch 12/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.3415 - binary_crossentropy: 0.0714 - dice_coef: 0.3884 - val_loss: 0.3565 - val_binary_crossentropy: 0.0714 - val_dice_coef: 0.3585
# Epoch 13/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.3275 - binary_crossentropy: 0.0671 - dice_coef: 0.4120 - val_loss: 0.3504 - val_binary_crossentropy: 0.0782 - val_dice_coef: 0.3775
# Epoch 14/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.3140 - binary_crossentropy: 0.0659 - dice_coef: 0.4379 - val_loss: 0.3642 - val_binary_crossentropy: 0.0853 - val_dice_coef: 0.3568
# Epoch 15/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.3123 - binary_crossentropy: 0.0648 - dice_coef: 0.4401 - val_loss: 0.3454 - val_binary_crossentropy: 0.0661 - val_dice_coef: 0.3754
# Epoch 16/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.3004 - binary_crossentropy: 0.0643 - dice_coef: 0.4635 - val_loss: 0.3511 - val_binary_crossentropy: 0.0755 - val_dice_coef: 0.3733
# Epoch 17/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2966 - binary_crossentropy: 0.0652 - dice_coef: 0.4720 - val_loss: 0.3434 - val_binary_crossentropy: 0.0734 - val_dice_coef: 0.3866
# Epoch 18/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2936 - binary_crossentropy: 0.0638 - dice_coef: 0.4765 - val_loss: 0.3413 - val_binary_crossentropy: 0.0826 - val_dice_coef: 0.4001
# Epoch 19/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2827 - binary_crossentropy: 0.0608 - dice_coef: 0.4954 - val_loss: 0.3461 - val_binary_crossentropy: 0.0766 - val_dice_coef: 0.3844
# Epoch 20/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2769 - binary_crossentropy: 0.0592 - dice_coef: 0.5055 - val_loss: 0.3559 - val_binary_crossentropy: 0.0826 - val_dice_coef: 0.3708
# Epoch 21/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2609 - binary_crossentropy: 0.0565 - dice_coef: 0.5346 - val_loss: 0.3477 - val_binary_crossentropy: 0.0797 - val_dice_coef: 0.3842
# Epoch 22/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2675 - binary_crossentropy: 0.0586 - dice_coef: 0.5236 - val_loss: 0.3362 - val_binary_crossentropy: 0.0705 - val_dice_coef: 0.3980
# Epoch 23/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2616 - binary_crossentropy: 0.0564 - dice_coef: 0.5333 - val_loss: 0.3331 - val_binary_crossentropy: 0.0671 - val_dice_coef: 0.4008
# Epoch 24/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2597 - binary_crossentropy: 0.0556 - dice_coef: 0.5362 - val_loss: 0.3227 - val_binary_crossentropy: 0.0748 - val_dice_coef: 0.4293
# Epoch 25/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2469 - binary_crossentropy: 0.0544 - dice_coef: 0.5606 - val_loss: 0.3445 - val_binary_crossentropy: 0.0719 - val_dice_coef: 0.3829
# Epoch 26/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2474 - binary_crossentropy: 0.0542 - dice_coef: 0.5594 - val_loss: 0.3535 - val_binary_crossentropy: 0.0846 - val_dice_coef: 0.3777
# Epoch 27/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2439 - binary_crossentropy: 0.0532 - dice_coef: 0.5653 - val_loss: 0.3274 - val_binary_crossentropy: 0.0767 - val_dice_coef: 0.4219
# Epoch 28/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2341 - binary_crossentropy: 0.0510 - dice_coef: 0.5827 - val_loss: 0.3264 - val_binary_crossentropy: 0.0743 - val_dice_coef: 0.4214
# Epoch 29/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2294 - binary_crossentropy: 0.0502 - dice_coef: 0.5913 - val_loss: 0.3365 - val_binary_crossentropy: 0.0864 - val_dice_coef: 0.4135
# Epoch 30/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2299 - binary_crossentropy: 0.0510 - dice_coef: 0.5912 - val_loss: 0.3259 - val_binary_crossentropy: 0.0749 - val_dice_coef: 0.4232
# Epoch 31/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2162 - binary_crossentropy: 0.0483 - dice_coef: 0.6158 - val_loss: 0.3455 - val_binary_crossentropy: 0.0699 - val_dice_coef: 0.3788
# Epoch 32/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.2095 - binary_crossentropy: 0.0459 - dice_coef: 0.6269 - val_loss: 0.3398 - val_binary_crossentropy: 0.0845 - val_dice_coef: 0.4050
# Epoch 33/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.2043 - binary_crossentropy: 0.0461 - dice_coef: 0.6375 - val_loss: 0.3216 - val_binary_crossentropy: 0.0764 - val_dice_coef: 0.4332
# Epoch 34/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1945 - binary_crossentropy: 0.0437 - dice_coef: 0.6546 - val_loss: 0.3328 - val_binary_crossentropy: 0.0765 - val_dice_coef: 0.4109
# Epoch 35/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1860 - binary_crossentropy: 0.0420 - dice_coef: 0.6699 - val_loss: 0.3464 - val_binary_crossentropy: 0.0830 - val_dice_coef: 0.3902
# Epoch 36/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.1778 - binary_crossentropy: 0.0400 - dice_coef: 0.6843 - val_loss: 0.3367 - val_binary_crossentropy: 0.0838 - val_dice_coef: 0.4104
# Epoch 37/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1769 - binary_crossentropy: 0.0406 - dice_coef: 0.6869 - val_loss: 0.3386 - val_binary_crossentropy: 0.0785 - val_dice_coef: 0.4013
# Epoch 38/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.1736 - binary_crossentropy: 0.0394 - dice_coef: 0.6921 - val_loss: 0.3417 - val_binary_crossentropy: 0.0853 - val_dice_coef: 0.4018
# Epoch 39/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1655 - binary_crossentropy: 0.0384 - dice_coef: 0.7074 - val_loss: 0.3355 - val_binary_crossentropy: 0.0826 - val_dice_coef: 0.4115
# Epoch 40/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1591 - binary_crossentropy: 0.0366 - dice_coef: 0.7185 - val_loss: 0.3487 - val_binary_crossentropy: 0.0971 - val_dice_coef: 0.3996
# Epoch 41/50
# 33/33 [==============================] - 57s 2s/step - loss: 0.1577 - binary_crossentropy: 0.0364 - dice_coef: 0.7211 - val_loss: 0.3492 - val_binary_crossentropy: 0.0900 - val_dice_coef: 0.3916
# Epoch 42/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1532 - binary_crossentropy: 0.0355 - dice_coef: 0.7290 - val_loss: 0.3491 - val_binary_crossentropy: 0.0929 - val_dice_coef: 0.3947
# Epoch 43/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1525 - binary_crossentropy: 0.0355 - dice_coef: 0.7305 - val_loss: 0.3273 - val_binary_crossentropy: 0.0899 - val_dice_coef: 0.4353
# Epoch 44/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1457 - binary_crossentropy: 0.0340 - dice_coef: 0.7427 - val_loss: 0.3442 - val_binary_crossentropy: 0.0889 - val_dice_coef: 0.4005
# Epoch 45/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1450 - binary_crossentropy: 0.0337 - dice_coef: 0.7438 - val_loss: 0.3556 - val_binary_crossentropy: 0.1041 - val_dice_coef: 0.3930
# Epoch 46/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1448 - binary_crossentropy: 0.0339 - dice_coef: 0.7444 - val_loss: 0.3500 - val_binary_crossentropy: 0.0919 - val_dice_coef: 0.3919
# Epoch 47/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1433 - binary_crossentropy: 0.0332 - dice_coef: 0.7466 - val_loss: 0.3439 - val_binary_crossentropy: 0.0919 - val_dice_coef: 0.4041
# Epoch 48/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1404 - binary_crossentropy: 0.0327 - dice_coef: 0.7519 - val_loss: 0.3564 - val_binary_crossentropy: 0.0853 - val_dice_coef: 0.3726
# Epoch 49/50
# 33/33 [==============================] - 55s 2s/step - loss: 0.1345 - binary_crossentropy: 0.0311 - dice_coef: 0.7621 - val_loss: 0.3590 - val_binary_crossentropy: 0.0990 - val_dice_coef: 0.3810
# Epoch 50/50
# 33/33 [==============================] - 56s 2s/step - loss: 0.1283 - binary_crossentropy: 0.0300 - dice_coef: 0.7733 - val_loss: 0.3576 - val_binary_crossentropy: 0.1020 - val_dice_coef: 0.3869

# %%
preds_train5 = model5.predict(datagen_train_5)
preds_test5 = model5.predict(datagen_test_5)
# Out:
# 33/33 [==============================] - 50s 2s/step
# 4/4 [==============================] - 5s 1s/step

# %%
Plot_loss(history5)

# %%
graficar_pred(datagen_train_5,preds_train5)

graficar_pred(datagen_test_5,preds_test5)

# %%
model5.evaluate(datagen_test_5)
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 0.3310 - binary_crossentropy: 0.0863 - dice_coef: 0.4242
# [0.33104005455970764, 0.08628172427415848, 0.424201637506485]

# %% [markdown]
# Como puede verse en el gráfico de dice y de loss de testeo vs validación, pareciera que aún habia mas espacio para el overfitteo del sistema con estos parametros, por lo que corriendo mas epochs podría conseguirse un dice para train muiy cercano aq uno, logrando un sistema  con un gran overfitting. A partir de este modelo, deberían probarse distintos métodos de regularización (como l2 por ejemplo o dropout) para ver si se puede reducir el overfitting y lograr que el modelo se adapte tambien mejor a imagenes generales distintas a las del conjunto de testeo.
# Puede evrse tambien que al aumentar los epochs no se lograrísa una mejora en la predicción en conjuntos distintos al de entrenamiento, viendo como el coeficiente de dice y la loss de validación se estancan luego de aproximadamente 20 epochs. Cabe destacar que aqui se consiguio el mejor dice para el conjunto de testeo, con 0.42

# %% [markdown]
# ### MODELO 6

# %%
batch = 64
batchnorm = False
depth = 5
dropout = False
epochs = 20
transform =A.Compose([
    A.HorizontalFlip(p=0.5),
    A.OneOf([
        A.RandomContrast(),
        A.RandomGamma(),
        A.RandomBrightness(),
         ], p=0.3),
    A.OneOf([
        A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
        A.GridDistortion(),
        A.OpticalDistortion(distort_limit=2, shift_limit=0.5),
        ], p=0.3)
],p=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1641: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1615: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,

# %%
datagen_train_6 = datagen(batch = batch, train = True , val = False, transformm = transform)
datagen_val_6 = datagen(batch = batch, train = False , val = True, transformm = False)
datagen_test_6 = datagen(batch = batch, train = False , val = False, transformm = False)

# %%
# instanciación del modelo
model6 = UNet((128,128,1),start_ch=32,depth=depth,batchnorm=batchnorm, residual = True,dropout=dropout)
# compilación
model6.compile(loss=dice_coef_loss, optimizer="adam", metrics=["binary_crossentropy", dice_coef])

# %%
history6 = model6.fit(datagen_train_6, epochs = epochs, validation_data=datagen_val_6)
# Out:
# Epoch 1/20
# 33/33 [==============================] - 63s 2s/step - loss: 0.6165 - binary_crossentropy: 0.2542 - dice_coef: 0.0212 - val_loss: 0.5156 - val_binary_crossentropy: 0.0770 - val_dice_coef: 0.0459
# Epoch 2/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4938 - binary_crossentropy: 0.0801 - dice_coef: 0.0924 - val_loss: 0.5033 - val_binary_crossentropy: 0.0837 - val_dice_coef: 0.0771
# Epoch 3/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.4790 - binary_crossentropy: 0.0857 - dice_coef: 0.1276 - val_loss: 0.4636 - val_binary_crossentropy: 0.0871 - val_dice_coef: 0.1600
# Epoch 4/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4634 - binary_crossentropy: 0.0878 - dice_coef: 0.1610 - val_loss: 0.4519 - val_binary_crossentropy: 0.0862 - val_dice_coef: 0.1825
# Epoch 5/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4462 - binary_crossentropy: 0.0858 - dice_coef: 0.1935 - val_loss: 0.4386 - val_binary_crossentropy: 0.0850 - val_dice_coef: 0.2079
# Epoch 6/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.4321 - binary_crossentropy: 0.0860 - dice_coef: 0.2219 - val_loss: 0.4281 - val_binary_crossentropy: 0.0751 - val_dice_coef: 0.2189
# Epoch 7/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4227 - binary_crossentropy: 0.0833 - dice_coef: 0.2379 - val_loss: 0.4175 - val_binary_crossentropy: 0.0818 - val_dice_coef: 0.2468
# Epoch 8/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4108 - binary_crossentropy: 0.0811 - dice_coef: 0.2595 - val_loss: 0.4183 - val_binary_crossentropy: 0.0971 - val_dice_coef: 0.2604
# Epoch 9/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.4040 - binary_crossentropy: 0.0808 - dice_coef: 0.2729 - val_loss: 0.4184 - val_binary_crossentropy: 0.0866 - val_dice_coef: 0.2497
# Epoch 10/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3999 - binary_crossentropy: 0.0810 - dice_coef: 0.2811 - val_loss: 0.4001 - val_binary_crossentropy: 0.0934 - val_dice_coef: 0.2931
# Epoch 11/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3933 - binary_crossentropy: 0.0805 - dice_coef: 0.2939 - val_loss: 0.3893 - val_binary_crossentropy: 0.0839 - val_dice_coef: 0.3053
# Epoch 12/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.3923 - binary_crossentropy: 0.0802 - dice_coef: 0.2957 - val_loss: 0.3862 - val_binary_crossentropy: 0.0727 - val_dice_coef: 0.3004
# Epoch 13/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3768 - binary_crossentropy: 0.0775 - dice_coef: 0.3238 - val_loss: 0.3663 - val_binary_crossentropy: 0.0767 - val_dice_coef: 0.3441
# Epoch 14/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3710 - binary_crossentropy: 0.0763 - dice_coef: 0.3343 - val_loss: 0.3743 - val_binary_crossentropy: 0.0751 - val_dice_coef: 0.3265
# Epoch 15/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.3614 - binary_crossentropy: 0.0746 - dice_coef: 0.3518 - val_loss: 0.3666 - val_binary_crossentropy: 0.0663 - val_dice_coef: 0.3331
# Epoch 16/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3639 - binary_crossentropy: 0.0760 - dice_coef: 0.3483 - val_loss: 0.3783 - val_binary_crossentropy: 0.0868 - val_dice_coef: 0.3302
# Epoch 17/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3716 - binary_crossentropy: 0.0771 - dice_coef: 0.3340 - val_loss: 0.3691 - val_binary_crossentropy: 0.0743 - val_dice_coef: 0.3361
# Epoch 18/20
# 33/33 [==============================] - 59s 2s/step - loss: 0.3516 - binary_crossentropy: 0.0715 - dice_coef: 0.3684 - val_loss: 0.3408 - val_binary_crossentropy: 0.0717 - val_dice_coef: 0.3901
# Epoch 19/20
# 33/33 [==============================] - 57s 2s/step - loss: 0.3533 - binary_crossentropy: 0.0732 - dice_coef: 0.3667 - val_loss: 0.3586 - val_binary_crossentropy: 0.0783 - val_dice_coef: 0.3612
# Epoch 20/20
# 33/33 [==============================] - 58s 2s/step - loss: 0.3498 - binary_crossentropy: 0.0733 - dice_coef: 0.3738 - val_loss: 0.3470 - val_binary_crossentropy: 0.0760 - val_dice_coef: 0.3820

# %% [markdown]
# Sobre este ultimo modelo no se pudieron obtener mas resultados, dado que se desconectó en entorno de ejecución, por lo que se perdieron todas las variables y modelos entrenados y n ose disponía de mas uso de GPU de Google para continuar. De todos modos, puede verse un coeficiente de dice de validacion de 0.38 y de test de 0.349, por lo que la transformación no pareciera haber generado una gran mejora en el entrenamiento.
